# %% [markdown]
# # Pandas Library

# %%
# first we need to import pandas.  Convention is variable pd
import pandas as pd

# make a list and dict to use pandas on
simple_list = ['apples', 'oranges', 'bananas', 'pears']

# %%
# print out list
print('First list item (simple_list[0]) is {0}'.format(simple_list[0]))
print('Third list item (simple_list[2]) is {0}'.format(simple_list[2]))
print('Last list item (simple_list[-1]) is {0}'.format(simple_list[-1]))
print('2nd last list item (simple_list[-2]) is {0}'.format(simple_list[-2]))
# Out:
# First list item (simple_list[0]) is apples
# Third list item (simple_list[2]) is bananas
# Last list item (simple_list[-1]) is pears
# 2nd last list item (simple_list[-2]) is bananas

# %% [markdown]
# Make a simple dictionary

# %%
simple_dict = {1:'one', 2:'two', 4:'four', 3:'three'}
print("Item with key (index) '4' has value: {}".format(simple_dict[4]))
# Out:
# Item with key (index) '4' has value: four

# %% [markdown]
# We can iterate through all keys using for loop

# %%
for key in simple_dict:
    print(simple_dict[key])
# Out:
# one
# two
# three
# four

# %% [markdown]
# <span style="color:#3388CC">
# Indigo note.
# </span>

# %% [markdown]
# Or we can use _list comprehension_<span style="color:#3A9C35">
# Kuma
# </span>
# iterm
#
# test

# %%
print(list(simple_dict.keys()))
print(list(simple_dict.values()))
# Out:
# [1, 2, 3, 4]
# ['one', 'two', 'three', 'four']

# %% [markdown]
# we can use a list or dict comprehension to filter the contents of an object according to a test condition.

# %%
[simple_dict[k] for k in simple_dict if k>2]
# Out:
# ['three', 'four']

# %% [markdown]
# Simple way to reverse a dictionary using zip()

# %%
# zip into a collection of tuples
alt_dict = zip(simple_dict.values(), simple_dict.keys())
for e in alt_dict:
    print(e)
# Out:
# ('one', 1)
# ('two', 2)
# ('three', 3)
# ('four', 4)

# %%
# concise method:
alternative_dict = dict(zip(simple_dict.values(), simple_dict.keys()))

print(alternative_dict)
# Out:
# {'four': 4, 'two': 2, 'one': 1, 'three': 3}

# %% [markdown]
# ## Pandas Series and Dataframes

# %%
pd.Series( ['one', 'two', 'three', 'four'] )
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# dtype: object

# %%
# we can simplify the creation of a Series by importingi it from pandas directly
from pandas import Series
simple_series = Series( [101, 102, 103, 104])
simple_series
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# dtype: int64

# %%
simple_series[1]
# Out:
# 102

# %%
simple_series[[1, 0, 3]]
# Out:
# 1    102
# 0    101
# 3    104
# dtype: int64

# %%
myindex_series = Series( ['apple', 'orange', 'pear', 'plum'],
                       index=['one', 'two', 'three', 'four'])
print(myindex_series.index)
myindex_series
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')
# one       apple
# two      orange
# three      pear
# four       plum
# dtype: object

# %% [markdown]
# ## Investigating a file

# %% [markdown]
# ### Take a peak at the firs few lines of a file

# %%
# !ls 'TM351_part_02_notebooks/data/iwCouncilSpending/'
# Out:
# csvFromWeb.csv	PUBLISHED FORMAT - NOV 2013.csv  sample1.csv  sample2.csv

# %%
# !head -n 5 TM351_part_02_notebooks/data/iwCouncilSpending/PUBLISHED\ FORMAT\ -\ NOV\ 2013.csv
# Out:
# Capital or Revenue,Directorate,Transaction Number,Date,Service Area,Expenses Type,Amount,Supplier Name
# Revenue,Community Wellbeing & Social Care,5105636098,13.11.2013,Public Libraries Central,Marketing Costs,200.00,REDACTED PERSONAL DATA
# Revenue,Community Wellbeing & Social Care,5105635705,08.11.2013,Drug Misuse - Adults,Charges from Independent Providers,120.00,REDACTED PERSONAL DATA
# Revenue,Childrens Services,5105637261,20.11.2013,Thompson House Tuition Centre (PRU),Professional Services,240.00,* M BOWDERY T/A SPOTLIGHT BOUTIQUE
# Revenue,Community Wellbeing & Social Care,5105637069,27.11.2013,Safeguarding Adults,Professional Services,"5,285.00",REDACTED PERSONAL DATA

# %% [markdown]
# ### get a line count
# using th -l switch to count lines
#
# This line count is the upper bound as some data may be split over several lines

# %%
# !wc -l 'TM351_part_02_notebooks/data/iwCouncilSpending/PUBLISHED FORMAT - NOV 2013.csv'
# Out:
# 11413 TM351_part_02_notebooks/data/iwCouncilSpending/PUBLISHED FORMAT - NOV 2013.csv

# %% [markdown]
# ### We can also peak at last few lines
# this is useful to check whether there is any blank lines at tthe end of a file

# %%
# !tail -n 6 'TM351_part_02_notebooks/data/iwCouncilSpending/PUBLISHED FORMAT - NOV 2013.csv'
# Out:
# Revenue,Community Wellbeing & Social Care,GPC,27.11.2013,Workforce Development -  Westridge Centre,Catering Purchases,30.58,TESCO STORE 5567
# Revenue,Economy & Environment,GPC,31.10.2013,Play Development,Operational Equipment,127.99,GLENWAY PRODUCTS LTD
# Revenue,Economy & Environment,GPC,04.11.2013,Play Development,Operational Equipment,91.99,GREENHAM TRADING LTD
# Revenue,Economy & Environment,GPC,06.11.2013,Play Development,Travel Expenses,470.70,WIGHTLINK
# Revenue,Economy & Environment,GPC,13.11.2013,Play Development,Operational Equipment,108.42,WWW.SPORTSFRONT.CO.UK
# Revenue,Economy & Environment,GPC,14.11.2013,Sports Development - Admin,Training,12.50,WWW.RFU.COM

# %% [markdown]
# ## Reading in CSV files
#
# _pandas_ provides utilities for reading and writing CSV files so we will use it

# %%
import pandas as pd

# %%
pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample1.csv')
# Out:
#   Capital or Revenue                        Directorate  Transaction Number  \
# 0            Revenue  Community Wellbeing & Social Care          5105636098
# 1            Revenue  Community Wellbeing & Social Care          5105635705
# 2            Revenue                 Childrens Services          5105637261
# 3            Revenue  Community Wellbeing & Social Care          5105637069
# 4            Revenue  Community Wellbeing & Social Care          5105637605
# 5            Revenue  Community Wellbeing & Social Care          5105637605
# 6            Revenue  Community Wellbeing & Social Care          5105637605
# 7            Revenue  Community Wellbeing & Social Care          5105637605
# 8            Revenue  Community Wellbeing & Social Care          5105637605
#
#          Date                         Service Area  \
# 0  13.11.2013             Public Libraries Central
# 1  08.11.2013                 Drug Misuse - Adults
# 2  20.11.2013  Thompson House Tuition Centre (PRU)
# 3  27.11.2013                  Safeguarding Adults
# 4  22.11.2013                     Leaseholds by LA
# 5  22.11.2013                     Leaseholds by LA
# 6  22.11.2013                     Leaseholds by LA
# 7  22.11.2013                     Leaseholds by LA
# 8  22.11.2013                     Leaseholds by LA
#
#                                 Expenses Type    Amount  \
# 0                             Marketing Costs    200.00
# 1          Charges from Independent Providers    120.00
# 2                       Professional Services    240.00
# 3                       Professional Services  5,285.00
# 4  Accommodation Costs - Leaseholder Payments    695.89
# 5  Accommodation Costs - Leaseholder Payments    695.89
# 6  Accommodation Costs - Leaseholder Payments    695.89
# 7  Accommodation Costs - Leaseholder Payments    695.89
# 8  Accommodation Costs - Leaseholder Payments    695.89
#
#                         Supplier Name
# 0              REDACTED PERSONAL DATA
# 1              REDACTED PERSONAL DATA
# 2  * M BOWDERY T/A SPOTLIGHT BOUTIQUE
# 3              REDACTED PERSONAL DATA
# 4              REDACTED PERSONAL DATA
# 5              REDACTED PERSONAL DATA
# 6              REDACTED PERSONAL DATA
# 7              REDACTED PERSONAL DATA
# 8              REDACTED PERSONAL DATA

# %% [markdown]
# ### be careful of encodings

# %%
#pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample2.csv')
import chardet
testfile = open('TM351_part_02_notebooks/data/iwCouncilSpending/sample2.csv', 'rb').read()
chardet.detect(testfile)
# Out:
# {'confidence': 0.73, 'encoding': 'windows-1252'}

# %%
pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample2.csv', encoding='windows-1252')
# Out:
#    Revenue  Community Wellbeing & Social Care  GPC  23.11.2013  \
# 0  Revenue  Community Wellbeing & Social Care  GPC  27.11.2013
# 1  Revenue                          Resources  GPC  27.11.2013
# 2  Revenue  Community Wellbeing & Social Care  GPC  27.11.2013
# 3  Revenue  Community Wellbeing & Social Care  GPC  27.11.2013
# 4  Revenue              Economy & Environment  GPC  31.10.2013
# 5  Revenue              Economy & Environment  GPC  04.11.2013
# 6  Revenue              Economy & Environment  GPC  06.11.2013
# 7  Revenue              Economy & Environment  GPC  13.11.2013
# 8  Revenue              Economy & Environment  GPC  14.11.2013
#
#                         Training - Childrens               Licences   28.96  \
# 0        Workforce Development - Early Years                Postage    6.95
# 1    Organisational Development – Leadership  Professional Services   28.90
# 2                           Hub Coordinators        Travel Expenses   25.00
# 3  Workforce Development -  Westridge Centre     Catering Purchases   30.58
# 4                           Play Development  Operational Equipment  127.99
# 5                           Play Development  Operational Equipment   91.99
# 6                           Play Development        Travel Expenses  470.70
# 7                           Play Development  Operational Equipment  108.42
# 8                 Sports Development - Admin               Training   12.50
#
#                  SURVEYMONKEY.COM
# 0            POST OFFICE COUNTERS
# 1  WWW.PRINTEDPAPERPRODUCTS.CO.UK
# 2                STAGECOACH SOUTH
# 3                TESCO STORE 5567
# 4            GLENWAY PRODUCTS LTD
# 5            GREENHAM TRADING LTD
# 6                       WIGHTLINK
# 7           WWW.SPORTSFRONT.CO.UK
# 8                     WWW.RFU.COM

# %% [markdown]
# ### read in n lines of a file

# %%
sample2 = pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample2.csv', encoding='windows-1252', nrows=3)

# %%
origNames =  sample2.columns.values.tolist()
origNames
# Out:
# ['Revenue',
#  'Community Wellbeing & Social Care',
#  'GPC',
#  '23.11.2013',
#  'Training - Childrens',
#  'Licences',
#  '28.96',
#  'SURVEYMONKEY.COM']

# %% [markdown]
# ### read file in as chunks

# %%
chunks = pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample2.csv',encoding='windows-1252',chunksize=4)

# %%
for chunk in chunks:
    print("New chunk...")
    print(chunk[['Revenue', 'Licences']])
# Out:
# New chunk...
#    Revenue               Licences
# 0  Revenue                Postage
# 1  Revenue  Professional Services
# 2  Revenue        Travel Expenses
# 3  Revenue     Catering Purchases
# New chunk...
#    Revenue               Licences
# 4  Revenue  Operational Equipment
# 5  Revenue  Operational Equipment
# 6  Revenue        Travel Expenses
# 7  Revenue  Operational Equipment
# New chunk...
#    Revenue  Licences
# 8  Revenue  Training

# %% [markdown]
# ### import a csv from a url

# %%
url = 'http://www.iwight.com/documentlibrary/download/november-2013-transparency-data-csv'

import requests
resp = requests.get(url)
resp.content[:103]
# Out:
# b'Capital or Revenue,Directorate,Transaction Number,Date,Service Area,Expenses Type,Amount,Supplier Name\r'

# %%
# b shows it is a byte object now use chardet to detect
import chardet
chardet.detect(resp.content)
# Out:
# {'confidence': 0.73, 'encoding': 'windows-1252'}

# %%
csvfromweb = pd.read_csv(url, encoding = 'windows-1252')
csvfromweb.head(5)
# Out:
#   Capital or Revenue                        Directorate Transaction Number  \
# 0            Revenue  Community Wellbeing & Social Care         5105636098
# 1            Revenue  Community Wellbeing & Social Care         5105635705
# 2            Revenue                 Childrens Services         5105637261
# 3            Revenue  Community Wellbeing & Social Care         5105637069
# 4            Revenue  Community Wellbeing & Social Care         5105637605
#
#          Date                         Service Area  \
# 0  13.11.2013             Public Libraries Central
# 1  08.11.2013                 Drug Misuse - Adults
# 2  20.11.2013  Thompson House Tuition Centre (PRU)
# 3  27.11.2013                  Safeguarding Adults
# 4  22.11.2013                     Leaseholds by LA
#
#                                 Expenses Type    Amount  \
# 0                             Marketing Costs    200.00
# 1          Charges from Independent Providers    120.00
# 2                       Professional Services    240.00
# 3                       Professional Services  5,285.00
# 4  Accommodation Costs - Leaseholder Payments    695.89
#
#                         Supplier Name
# 0              REDACTED PERSONAL DATA
# 1              REDACTED PERSONAL DATA
# 2  * M BOWDERY T/A SPOTLIGHT BOUTIQUE
# 3              REDACTED PERSONAL DATA
# 4              REDACTED PERSONAL DATA

# %% [markdown]
# ## Write DF to CSV files

# %%
csvfromweb.to_csv('TM351_part_02_notebooks/data/iwCouncilSpending/csvfromweb_a.csv')
# chow first few lines to prove written
pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/csvfromweb_a.csv', nrows=5)
# Out:
#    Unnamed: 0 Capital or Revenue                        Directorate  \
# 0           0            Revenue  Community Wellbeing & Social Care
# 1           1            Revenue  Community Wellbeing & Social Care
# 2           2            Revenue                 Childrens Services
# 3           3            Revenue  Community Wellbeing & Social Care
# 4           4            Revenue  Community Wellbeing & Social Care
#
#    Transaction Number        Date                         Service Area  \
# 0          5105636098  13.11.2013             Public Libraries Central
# 1          5105635705  08.11.2013                 Drug Misuse - Adults
# 2          5105637261  20.11.2013  Thompson House Tuition Centre (PRU)
# 3          5105637069  27.11.2013                  Safeguarding Adults
# 4          5105637605  22.11.2013                     Leaseholds by LA
#
#                                 Expenses Type    Amount  \
# 0                             Marketing Costs    200.00
# 1          Charges from Independent Providers    120.00
# 2                       Professional Services    240.00
# 3                       Professional Services  5,285.00
# 4  Accommodation Costs - Leaseholder Payments    695.89
#
#                         Supplier Name
# 0              REDACTED PERSONAL DATA
# 1              REDACTED PERSONAL DATA
# 2  * M BOWDERY T/A SPOTLIGHT BOUTIQUE
# 3              REDACTED PERSONAL DATA
# 4              REDACTED PERSONAL DATA

# %% [markdown]
# Files without header rows or index

# %%
csvfromweb.to_csv('TM351_part_02_notebooks/data/iwCouncilSpending/csvfromweb_unheaded.csv', index=False, header=False)
pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending
# 3                           Professional Services  5,285.00
# 4      Accommodation Costs - Leaseholder Payments    695.89
# 5      Accommodation Costs - Leaseholder Payments    695.89
# 6      Accommodation Costs - Leaseholder Payments    695.89
# 7      Accommodation Costs - Leaseholder Payments    695.89
# 8      Accommodation Costs - Leaseholder Payments    695.89
# 9                           Professional Services    216.90
# 10                              General Materials    495.00
# 11                               Office Equipment    826.50
# 12                           Transport of Clients    383.50
# 13                          Security of Buildings    120.00
# 14                          Security of Buildings     50.00
# 15                          Security of Buildings    120.00
# 16                          Security of Buildings     30.00
# 17                          Security of Buildings     25.00
# 18                          Security of Buildings    310.00
# 19                          Security of Buildings     65.00
# 20                          Security of Buildings    310.00
# 21                          Security of Buildings    155.00
# 22                          Security of Buildings     25.00
# 23                          Security of Buildings     60.00
# 24                          Security of Buildings     80.00
# 25                          Security of Buildings    620.00
# 26                    Capital Contractor Payments    100.00
# 27                    Capital Contractor Payments     80.00
# 28                    Capital Contractor Payments    100.00
# 29                    Capital Contractor Payments    100.00
# ...                                           ...       ...
# 11382                          Catering Purchases     18.05
# 11383                                    Training      5.10
# 11384                             Travel Expenses     48.70
# 11385                             Travel Expenses     47.60
# 11386                          Catering Purchases      8.50
# 11387                          Catering Purchases      4.00
# 11388                          Catering Purchases     39.81
# 11389                           General Materials      9.99
# 11390                          Catering Purchases     34.21
# 11391                           General Materials      3.96
# 11392                           General Materials      7.07
# 11393                             Travel Expenses     48.70
# 11394                             Travel Expenses     32.00
# 11395                             Travel Expenses    157.80
# 11396                          Catering Purchases      4.00
# 11397                                    Licences     28.99
# 11398                                    Licences     28.99
# 11399                                    Licences     28.99
# 11400                                    Licences     28.99
# 11401                                    Licences     28.99
# 11402                                    Licences     28.96
# 11403                                     Postage      6.95
# 11404                       Professional Services     28.90
# 11405                             Travel Expenses     25.00
# 11406                          Catering Purchases     30.58
# 11407                       Operational Equipment    127.99
# 11408                       Operational Equipment     91.99
# 11409                             Travel Expenses    470.70
# 11410                       Operational Equipment    108.42
# 11411                                    Training     12.50
#
#                                         7
# 0                  REDACTED PERSONAL DATA
# 1                  REDACTED PERSONAL DATA
# 2      * M BOWDERY T/A SPOTLIGHT BOUTIQUE
# 3                  REDACTED PERSONAL DATA
# 4                  REDACTED PERSONAL DATA
# 5                  REDACTED PERSONAL DATA
# 6                  REDACTED PERSONAL DATA
# 7                  REDACTED PERSONAL DATA
# 8                  REDACTED PERSONAL DATA
# 9                  REDACTED PERSONAL DATA
# 10                 REDACTED PERSONAL DATA
# 11                 REDACTED PERSONAL DATA
# 12                 REDACTED PERSONAL DATA
# 13                 REDACTED PERSONAL DATA
# 14                 REDACTED PERSONAL DATA
# 15                 REDACTED PERSONAL DATA
# 16                 REDACTED PERSONAL DATA
# 17                 REDACTED PERSONAL DATA
# 18                 REDACTED PERSONAL DATA
# 19                 REDACTED PERSONAL DATA
# 20                 REDACTED PERSONAL DATA
# 21                 REDACTED PERSONAL DATA
# 22                 REDACTED PERSONAL DATA
# 23                 REDACTED PERSONAL DATA
# 24                 REDACTED PERSONAL DATA
# 25                 REDACTED PERSONAL DATA
# 26                 REDACTED PERSONAL DATA
# 27                 REDACTED PERSONAL DATA
# 28                 REDACTED PERSONAL DATA
# 29                 REDACTED PERSONAL DATA
# ...                                   ...
# 11382                    TESCO STORE 5567
# 11383     HUNTINGTONS DISEASE ASSOCIATION
# 11384                 WWW.WIGHTLINK.CO.UK
# 11385                    STAGECOACH SOUTH
# 11386                    TESCO STORE 5567
# 11387                    TESCO STORE 5567
# 11388                    TESCO STORE 5567
# 11389                 AMAZON  MARKTEPLACE
# 11390                    TESCO STORE 5567
# 11391                 AMAZON  MARKTEPLACE
# 11392                 AMAZON  MARKTEPLACE
# 11393                 WWW.WIGHTLINK.CO.UK
# 11394                   RED FUNNEL BOOKIT
# 11395                    STAGECOACH SOUTH
# 11396                    TESCO STORE 5567
# 11397                    SURVEYMONKEY.COM
# 11398                    SURVEYMONKEY.COM
# 11399                    SURVEYMONKEY.COM
# 11400                    SURVEYMONKEY.COM
# 11401                    SURVEYMONKEY.COM
# 11402                    SURVEYMONKEY.COM
# 11403                POST OFFICE COUNTERS
# 11404      WWW.PRINTEDPAPERPRODUCTS.CO.UK
# 11405                    STAGECOACH SOUTH
# 11406                    TESCO STORE 5567
# 11407                GLENWAY PRODUCTS LTD
# 11408                GREENHAM TRADING LTD
# 11409                           WIGHTLINK
# 11410               WWW.SPORTSFRONT.CO.UK
# 11411                         WWW.RFU.COM
#
# [11412 rows x 8 columns]

# %% [markdown]
# get original column names

# %%
origNames = csvfromweb.columns.values.tolist()
origNames
# Out:
# ['Capital or Revenue',
#  'Directorate',
#  'Transaction Number',
#  'Date',
#  'Service Area',
#  'Expenses Type',
#  'Amount',
#  'Supplier Name']

# %%
pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/csvfromweb_unheaded.csv', nrows=5, header=None, names=origNames)
# Out:
#   Capital or Revenue                        Directorate  Transaction Number  \
# 0            Revenue  Community Wellbeing & Social Care          5105636098
# 1            Revenue  Community Wellbeing & Social Care          5105635705
# 2            Revenue                 Childrens Services          5105637261
# 3            Revenue  Community Wellbeing & Social Care          5105637069
# 4            Revenue  Community Wellbeing & Social Care          5105637605
#
#          Date                         Service Area  \
# 0  13.11.2013             Public Libraries Central
# 1  08.11.2013                 Drug Misuse - Adults
# 2  20.11.2013  Thompson House Tuition Centre (PRU)
# 3  27.11.2013                  Safeguarding Adults
# 4  22.11.2013                     Leaseholds by LA
#
#                                 Expenses Type    Amount  \
# 0                             Marketing Costs    200.00
# 1          Charges from Independent Providers    120.00
# 2                       Professional Services    240.00
# 3                       Professional Services  5,285.00
# 4  Accommodation Costs - Leaseholder Payments    695.89
#
#                         Supplier Name
# 0              REDACTED PERSONAL DATA
# 1              REDACTED PERSONAL DATA
# 2  * M BOWDERY T/A SPOTLIGHT BOUTIQUE
# 3              REDACTED PERSONAL DATA
# 4              REDACTED PERSONAL DATA

# %% [markdown]
# read in only certain columns

# %%
tmp = pd.read_csv('TM351_part_02_notebooks/data/iwCouncilSpending/sample1.csv', nrows=3, usecols=['Date','Expenses Type','Amount'])
tmp
# Out:
#          Date                       Expenses Type  Amount
# 0  13.11.2013                     Marketing Costs   200.0
# 1  08.11.2013  Charges from Independent Providers   120.0
# 2  20.11.2013               Professional Services   240.0
