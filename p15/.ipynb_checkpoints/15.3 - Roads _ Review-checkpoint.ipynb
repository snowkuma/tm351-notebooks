# %% [markdown]
# # Roads - review
# do through the roads dataset and integrate it with the accidents data.

# %%
# import the required libraries
import pymongo
import datetime
import collections

import pandas as pd
import scipy.stats

import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (15, 15) # reset the base size of figure

import seaborn as sns

import folium

# %%
# Open a connection to the Mongo server, open the accidents database and name the collections of accidents and labels
client = pymongo.MongoClient('mongodb://localhost:27351/')

db = client.accidents
accidents = db.accidents
labels = db.labels
roads = db.roads

# %%
# Load the expanded names of keys and human-readable codes into memory
expanded_name = collections.defaultdict(str)
for e in labels.find({'expanded': {"$exists": True}}):
    expanded_name[e['label']] = e['expanded']
    
label_of = collections.defaultdict(str)
for l in labels.find({'codes': {"$exists": True}}):
    for c in l['codes']:
        try:
            label_of[l['label'], int(c)] = l['codes'][c]
        except ValueError: 
            label_of[l['label'], c] = l['codes'][c]

# %%
def results_to_table(results, index_name, column_name, results_name, 
                     fillna=None,
                     relabel_index=False, relabel_columns=False,
                     index_label=None, column_label=None):
    
    # Move items in dicts-of-dicts to the top level.
    def flatten(d):
        new_d = {}
        for k in d:
            if isinstance(d[k], dict):
                new_d.update(flatten(d[k]))
            else:
                new_d[k] = d[k]
        return new_d

    df = pd.DataFrame([flatten(r) for r in results])
    df = df.pivot(index=index_name, columns=column_name, values=results_name)
    
    # Optionally, fiddle with names and labels to make the DataFrame pretty.
    if not fillna is None:
        df.fillna(fillna, inplace=True)
    if relabel_columns:
        df.columns = [label_of[column_name, c] for c in df.columns]
    if relabel_index:
        df.index = [label_of[index_name, r] for r in df.index]
    if column_label:
        df.columns.name = column_label
    else:
        df.columns.name = column_name
    if index_label:
        df.index.name = index_label
    else:
        df.index.name = index_name
    return df

# %% [markdown]
# ## Looking at roads
# What is in a 'road' document?

# %%
roads.find_one()
# Out:
# {'A-Junction': 'LA Boundary',
#  'AADFYear': 2012,
#  'B-Junction': 'A4086',
#  'CP': 506,
#  'Fd2WMV': 29.0,
#  'FdAll_MV': 2108.0,
#  'FdBUS': 17.0,
#  'FdCar': 1599.0,
#  'FdHGV': 66.0,
#  'FdHGVA3': 3.0,
#  'FdHGVA5': 10.0,
#  'FdHGVA6': 7.0,
#  'FdHGVR2': 40.0,
#  'FdHGVR3': 2.0,
#  'FdHGVR4': 4.0,
#  'FdLGV': 397.0,
#  'FdPC': 20.0,
#  'Latitude': 53.12266010696906,
#  'LenNet': 8.4,
#  'LenNet_miles': 5.21,
#  'Longitude': -4.001657045120545,
#  'ONS GOR Name': 'Wales',
#  'ONS LA Name': 'Conwy',
#  'RCat': 'TR',
#  'Road': 'A5',
#  'S Ref E': 266150,
#  'S Ref N': 360260,
#  '_id': ObjectId('533ed2c589f6f9ee18bae9e5'),
#  'loc': {'coordinates': [-4.001657045120545, 53.12266010696906],
#   'type': 'Point'},
#  'nearby_accident_count': 1,
#  'nearby_accidents': ['201260N115372']}

# %% [markdown]
# It's a section of road with totals of different vehicle types that passed along that section. Road sections have two ends, either junctions or region boundaries. The `Fd...` keys are the number of vehicles of a particular class that passed this point (in the forward direction, but there's no 'reverse' direction specified).

# %% [markdown]
# What do the codes mean?

# %%
expanded_name['FdAll_MV']
# Out:
# 'All motor vehicles'

# %%
expanded_name['FdHGVA6']
# Out:
# 'Articulated HGV with six axles'

# %% [markdown]
# What are the road categories?

# %%
[(c, label_of['RCat', c]) for k, c in label_of if k == 'RCat']
# Out:
# [('UR', 'Rural U road'),
#  ('TR', 'Rural trunk road'),
#  ('PM', 'Principal motorway'),
#  ('PU', 'Urban principal road'),
#  ('BR', 'Rural B road'),
#  ('PR', 'Rural principal road'),
#  ('UU', 'Urban U road'),
#  ('CR', 'Rural C road'),
#  ('BU', 'Urban B road'),
#  ('CU', 'Urban C road'),
#  ('TU', 'Urban trunk road'),
#  ('TM', 'Trunk motorway')]

# %% [markdown]
# Note that not every road segment has a location. We'll have to bear that in mind when doing geographic analysis of the roads dataset.

# %%
roads.find({'loc': {'$exists':False}}).count()
# Out:
# 96

# %%
roads.find({'loc': {'$exists': True}}).count()
# Out:
# 17891

# %% [markdown]
# ## Plotting some road points
# To start with, we'll plot some road segments on the map to see where they are.  We'll reuse the map-making procedures from Notebook 15.1

# %%
def add_accidents_markers(the_map, query, number_of_sides=5, fill_color='#769d96', limit=0,
                     radius=5, rotation=54):
    for a in accidents.find(query, 
                            ['loc.coordinates'],
                            limit=limit):
        folium.RegularPolygonMarker(location=[a['loc']['coordinates'][1], a['loc']['coordinates'][0]], 
                     number_of_sides=number_of_sides, radius=radius, rotation=rotation,
                                   fill_color=fill_color).add_to(the_map)

# %%
def add_roads_markers(the_map, query, number_of_sides=5, fill_color='#769d96', limit=0,
                     radius=5, rotation=54):
    for r in roads.find(query, 
                        ['loc.coordinates'],
                       limit=limit):
        folium.RegularPolygonMarker(location=[r['loc']['coordinates'][1], r['loc']['coordinates'][0]], 
                     number_of_sides=number_of_sides, radius=radius, rotation=rotation,
                                   fill_color=fill_color).add_to(the_map)

# %%
m = folium.Map([55, -3], zoom_start=6)

add_roads_markers(m, {'loc': {'$exists': True}}, limit=1000)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This clearly shows that the road data covers Britain, but nothing in Ireland.

# %% [markdown]
# ## Milton Keynes
# Let's zoom in a bit on Milton Keynes, the home of the Open University.  This polygon defines the area we're interested in.

# %%
milton_keynes = {'type': 'Polygon',
                               'coordinates': [[[-0.869719, 52.066547], 
                                                [-0.651709, 52.066547], 
                                                [-0.651709, 51.997161], 
                                                [-0.869719, 51.997161],
                                                [-0.869719, 52.066547]
                                                ]]}

min_mk_lat = min(p[1] for p in milton_keynes['coordinates'][0])
max_mk_lat = max(p[1] for p in milton_keynes['coordinates'][0])
min_mk_lon = min(p[0] for p in milton_keynes['coordinates'][0])
max_mk_lon = max(p[0] for p in milton_keynes['coordinates'][0])

mk_centre = [min_mk_lat + (max_mk_lat - min_mk_lat) / 2, min_mk_lon + (max_mk_lon - min_mk_lon) / 2]

mk_region_query = {'loc': {'$geoWithin': {'$geometry': milton_keynes}}}

# %%
roads.find(mk_region_query).count()
# Out:
# 24

# %%
[r for r in roads.find(mk_region_query, 
                       {'FdAll_MV':1, 'Road':1, 'RCat':1, 'LenNet':1, '_id':0})]
# Out:
# [{'FdAll_MV': 18805.0, 'LenNet': 4.2, 'RCat': 'PU', 'Road': 'A4146'},
#  {'FdAll_MV': 32672.0, 'LenNet': 2.2, 'RCat': 'TU', 'Road': 'A5'},
#  {'FdAll_MV': 32141.0, 'LenNet': 1.8, 'RCat': 'TR', 'Road': 'A5'},
#  {'FdAll_MV': 17263.0, 'LenNet': 0.7, 'RCat': 'PU', 'Road': 'A421'},
#  {'FdAll_MV': 31404.0, 'LenNet': 3.2, 'RCat': 'PU', 'Road': 'A421'},
#  {'FdAll_MV': 20217.0, 'LenNet': 3.6, 'RCat': 'PU', 'Road': 'A422'},
#  {'FdAll_MV': 42642.0, 'LenNet': 1.9, 'RCat': 'TU', 'Road': 'A5'},
#  {'FdAll_MV': 35490.0, 'LenNet': 1.2, 'RCat': 'TR', 'Road': 'A5'},
#  {'FdAll_MV': 32366.0, 'LenNet': 4.0, 'RCat': 'TR', 'Road': 'A5'},
#  {'FdAll_MV': 29862.0, 'LenNet': 3.0, 'RCat': 'PU', 'Road': 'A422'},
#  {'FdAll_MV': 18107.0, 'LenNet': 2.8, 'RCat': 'PU', 'Road': 'A509'},
#  {'FdAll_MV': 23224.0, 'LenNet': 2.5, 'RCat': 'PU', 'Road': 'A509'},
#  {'FdAll_MV': 37847.0, 'LenNet': 4.3, 'RCat': 'TU', 'Road': 'A5'},
#  {'FdAll_MV': 16478.0, 'LenNet': 0.7, 'RCat': 'PR', 'Road': 'A509'},
#  {'FdAll_MV': 41262.0, 'LenNet': 0.5, 'RCat': 'PR', 'Road': 'A509'},
#  {'FdAll_MV': 23242.0, 'LenNet': 0.8, 'RCat': 'PR', 'Road': 'A4146'},
#  {'FdAll_MV': 23223.0, 'LenNet': 4.3, 'RCat': 'PU', 'Road': 'A421'},
#  {'FdAll_MV': 28182.0, 'LenNet': 0.5, 'RCat': 'PU', 'Road': 'A421'},
#  {'FdAll_MV': 25646.0, 'LenNet': 0.4, 'RCat': 'PR', 'Road': 'A421'},
#  {'FdAll_MV': 25541.0, 'LenNet': 2.1, 'RCat': 'PU', 'Road': 'A4146'},
#  {'FdAll_MV': 8840.0, 'LenNet': 3.3, 'RCat': 'PR', 'Road': 'A5130'},
#  {'FdAll_MV': 99696.0, 'LenNet': 4.6, 'RCat': 'TM', 'Road': 'M1'},
#  {'FdAll_MV': 11394.0, 'LenNet': 3.5, 'RCat': 'PR', 'Road': 'A5130'},
#  {'FdAll_MV': 27279.0, 'LenNet': 2.5, 'RCat': 'PR', 'Road': 'A421'}]

# %%
mk_region_query
# Out:
# {'loc': {'$geoWithin': {'$geometry': {'coordinates': [[[-0.869719, 52.066547],
#       [-0.651709, 52.066547],
#       [-0.651709, 51.997161],
#       [-0.869719, 51.997161],
#       [-0.869719, 52.066547]]],
#     'type': 'Polygon'}}}}

# %%
m = folium.Map(mk_centre, zoom_start=12)    
add_accidents_markers(m, mk_region_query, fill_color='#ff0000', number_of_sides=6, radius=4)
add_roads_markers(m, mk_region_query, fill_color='#0000ff', number_of_sides=4, radius=10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This clearly shows that not all roads have traffic flow data.

# %% [markdown]
# # Exploring the roads data
# Let's have a look at some of the numbers associated with the traffic flow data.  We'll load the data into a DataFrame and make some graphs.

# %% [markdown]
# How many of each type of road section are there, and how long are they?

# %%
pipeline = [{'$group': {'_id': '$RCat', 
                        'length': {'$avg': '$LenNet'},
                        'count': {'$sum': 1}}}]

results = list(roads.aggregate(pipeline))
results
# Out:
# [{'_id': 'PM', 'count': 38, 'length': 1.0894736842105264},
#  {'_id': 'TM', 'count': 1111, 'length': 3.2201800180018},
#  {'_id': 'TR', 'count': 1812, 'length': 4.467235099337748},
#  {'_id': 'PR', 'count': 6106, 'length': 4.515180150671471},
#  {'_id': 'PU', 'count': 8614, 'length': 1.238450197353146},
#  {'_id': 'TU', 'count': 306, 'length': 1.3468627450980393}]

# %%
# put these results into a data frame and look up the category labels
road_lens_df = pd.DataFrame(results)
road_lens_df.set_index('_id', inplace=True)
road_lens_df.index.name = 'RCat'
# look up each category name
road_lens_df['category'] = [label_of['RCat', c] for c in road_lens_df.index]
road_lens_df
# Out:
#       count    length              category
# RCat
# PM       38  1.089474    Principal motorway
# TM     1111  3.220180        Trunk motorway
# TR     1812  4.467235      Rural trunk road
# PR     6106  4.515180  Rural principal road
# PU     8614  1.238450  Urban principal road
# TU      306  1.346863      Urban trunk road

# %%
# plot as a scattes
plt.scatter(road_lens_df['count'],
            road_lens_df['length'])
plt.xlabel('Count')
plt.ylabel('Total length')

# add labels to each point
for r in road_lens_df.iterrows():
    plt.annotate(r[1]['category'], xy=(r[1]['count'], r[1]['length']),
                 xytext=(10, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# let's redo that plot as it isn't very pretty

# %%
# make the figure size mora appropriate
mpl.rcParams['figure.figsize'] = (8, 8)

# plot as a scattes
plt.scatter(road_lens_df['count'],
            road_lens_df['length'])
plt.xlabel('Count')
plt.ylabel('Total length')

# add labels to each point
for r in road_lens_df.iterrows():
    plt.annotate(r[1]['category'], xy=(r[1]['count'], r[1]['length']),
                 xytext=(10, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# Unsurprisingly, rural road sections are longer than urban road sections.  There are more 'principle' than 'trunk' road sections, probably because 'trunk' roads are designated major routes.
#
# But what are principle motorways?

# %%
roads.distinct('Road', {'RCat': 'PM'})
# Out:
# ['A57M',
#  'M65',
#  'A64M',
#  'M62',
#  'A329M',
#  'A167M',
#  'A601M',
#  'M56',
#  'M275',
#  'A38M',
#  'A58M',
#  'M55']

# %% [markdown]
# The average lengths shown so far don't tell us about the distribution of lengths of different roads.

# %%
road_lengths_df = pd.DataFrame(list(roads.find({}, ['RCat', 'LenNet'])))
road_lengths_df.describe()
# Out:
#              LenNet
# count  17987.000000
# mean       2.799994
# std        3.816937
# min        0.070000
# 25%        0.600000
# 50%        1.500000
# 75%        3.300000
# max       55.500000

# %%
road_lengths_df['LenNet'].hist()

# %% [markdown]
# Most road sections are very short, with a few that are longer.
#
# Is there a difference between rural and urban sections?

# %%
# categorize the data 
isUrban = road_lengths_df.apply(lambda r: r['RCat'][1] == 'U', axis=1)
isRural = road_lengths_df.apply(lambda r: r['RCat'][1] == 'R', axis=1)

# %%
road_lengths_df[isUrban]['LenNet'].describe()
# Out:
# count    8920.000000
# mean        1.242169
# std         1.078233
# min         0.070000
# 25%         0.400000
# 50%         0.900000
# 75%         1.700000
# max        10.600000
# Name: LenNet, dtype: float64

# %%
road_lengths_df[isRural]['LenNet'].describe()
# Out:
# count    7918.000000
# mean        4.504208
# std         4.949380
# min         0.100000
# 25%         1.100000
# 50%         2.800000
# 75%         6.175000
# max        55.500000
# Name: LenNet, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot()
road_lengths_df[isUrban]['LenNet'].hist(ax=ax, alpha=0.5, color='red')
road_lengths_df[isRural]['LenNet'].hist(ax=ax, alpha=0.5, color='green')

# %% [markdown]
# This shows that, while both urban and rural roads have a similar rhape of road length distributions (many short sections with some longer sections), the rural roads are much longer than the urban ones

# %% [markdown]
# ## Looking at districts
# Which districts have the most roads, and the longest roads?
#
# We'll use a pipeline to find the data and plot it on a scatter plot

# %%
pipeline = [{'$group': {'_id': '$ONS LA Name',
                        'length': {'$sum': '$LenNet'},
                        'count': {'$sum': 1}}}]
results = list(roads.aggregate(pipeline))
results
# Out:
# [{'_id': 'Isles of Scilly', 'count': 5, 'length': 7.7},
#  {'_id': 'Plymouth', 'count': 33, 'length': 42.0},
#  {'_id': 'Havering', 'count': 33, 'length': 61.3},
#  {'_id': 'Isle of Anglesey', 'count': 42, 'length': 174.1},
#  {'_id': 'Newcastle upon Tyne', 'count': 78, 'length': 89.9},
#  {'_id': 'Wakefield', 'count': 93, 'length': 203.96},
#  {'_id': 'Calderdale', 'count': 65, 'length': 148.0},
#  {'_id': 'York', 'count': 54, 'length': 96.32},
#  {'_id': 'Conwy', 'count': 61, 'length': 232.9},
#  {'_id': 'Trafford', 'count': 43, 'length': 67.9},
#  {'_id': 'Lincolnshire', 'count': 201, 'length': 1108.11},
#  {'_id': 'Halton', 'count': 43, 'length': 56.05},
#  {'_id': 'Liverpool', 'count': 165, 'length': 124.4},
#  {'_id': 'Barnsley', 'count': 76, 'length': 167.9},
#  {'_id': 'Islington', 'count': 64, 'length': 38.1},
#  {'_id': 'Bradford', 'count': 109, 'length': 154.7},
#  {'_id': 'Kent', 'count': 466, 'length': 1134.94},
#  {'_id': 'Warwickshire', 'count': 225, 'length': 619.0},
#  {'_id': 'Cumbria', 'count': 206, 'length': 1114.5},
#  {'_id': 'Wigan', 'count': 94, 'length': 135.0},
#  {'_id': 'Cambridgeshire', 'count': 161, 'length': 608.8},
#  {'_id': 'Fife', 'count': 132, 'length': 425.4},
#  {'_id': 'Caerphilly', 'count': 37, 'length': 95.8},
#  {'_id': 'Bexley', 'count': 58, 'length': 68.4},
#  {'_id': 'Gloucestershire', 'count': 199, 'length': 669.64},
#  {'_id': 'Wiltshire', 'count': 204, 'length': 708.1},
#  {'_id': 'City of London', 'count': 38, 'length': 12.85},
#  {'_id': 'Glasgow City', 'count': 170, 'length': 182.99},
#  {'_id': 'Hillingdon', 'count': 53, 'length': 82.7},
#  {'_id': 'Greenwich', 'count': 61, 'length': 65.9},
#  {'_id': 'Rotherham', 'count': 69, 'length': 134.1},
#  {'_id': 'Cornwall excluding Isles of Scilly', 'count': 158, 'length': 696.77},
#  {'_id': 'Buckinghamshire', 'count': 140, 'length': 424.12},
#  {'_id': 'Northamptonshire', 'count': 238, 'length': 722.8},
#  {'_id': 'Barnet', 'count': 98, 'length': 108.4},
#  {'_id': 'Bath and North East Somerset', 'count': 78, 'length': 133.4},
#  {'_id': 'Rochdale', 'count': 68, 'length': 108.25},
#  {'_id': 'Shetland Islands', 'count': 35, 'length': 225.0},
#  {'_id': 'East Dunbartonshire', 'count': 27, 'length': 52.1},
#  {'_id': 'Telford and Wrekin', 'count': 48, 'length': 95.4},
#  {'_id': 'Devon', 'count': 231, 'length': 1170.27},
#  {'_id': 'St. Helens', 'count': 67, 'length': 97.1},
#  {'_id': 'East Cheshire', 'count': 181, 'length': 469.6},
#  {'_id': 'Comhairle nan Eilean Siar', 'count': 28, 'length': 333.3},
#  {'_id': 'Sutton', 'count': 18, 'length': 29.4},
#  {'_id': 'Leicestershire', 'count': 183, 'length': 514.4},
#  {'_id': 'Blaenau Gwent', 'count': 20, 'length': 52.9},
#  {'_id': 'Cardiff', 'count': 59, 'length': 109.6},
#  {'_id': 'Doncaster', 'count': 78, 'length': 216.38},
#  {'_id': 'Rutland', 'count': 21, 'length': 95.5},
#  {'_id': 'Wirral', 'count': 91, 'length': 125.7},
#  {'_id': 'Stirling', 'count': 75, 'length': 337.7},
#  {'_id': 'Tower Hamlets', 'count': 52, 'length': 41.300000000000004},
#  {'_id': 'Bedford', 'count': 66, 'length': 109.27},
#  {'_id': 'Wrexham', 'count': 44, 'length': 128.3},
#  {'_id': 'South Lanarkshire', 'count': 98, 'length': 378.8},
#  {'_id': 'Portsmouth', 'count': 53, 'length': 57.8},
#  {'_id': 'Sunderland', 'count': 78, 'length': 106.03},
#  {'_id': 'Angus', 'count': 60, 'length': 242.71},
#  {'_id': 'Redbridge', 'count': 47, 'length': 61.0},
#  {'_id': 'Torbay', 'count': 29, 'length': 45.2},
#  {'_id': 'Central Bedfordshire', 'count': 83, 'length': 209.7},
#  {'_id': 'Blackpool', 'count': 38, 'length': 41.0},
#  {'_id': 'Lancashire', 'count': 347, 'length': 863.5},
#  {'_id': 'Nottingham', 'count': 87, 'length': 72.7},
#  {'_id': 'East Renfrewshire', 'count': 17, 'length': 50.65},
#  {'_id': 'Somerset', 'count': 212, 'length': 764.45},
#  {'_id': 'Midlothian', 'count': 61, 'length': 114.99},
#  {'_id': 'South Ayrshire', 'count': 48, 'length': 201.4},
#  {'_id': 'Rhondda, Cynon, Taff', 'count': 67, 'length': 187.0},
#  {'_id': 'Staffordshire', 'count': 345, 'length': 857.5},
#  {'_id': 'Merthyr Tydfil', 'count': 30, 'length': 58.5},
#  {'_id': 'Powys', 'count': 112, 'length': 660.5},
#  {'_id': 'Surrey', 'count': 351, 'length': 721.09},
#  {'_id': 'Bridgend', 'count': 45, 'length': 115.59},
#  {'_id': 'Durham', 'count': 128, 'length': 441.5},
#  {'_id': 'Torfaen', 'count': 12, 'length': 35.0},
#  {'_id': 'Monmouthshire', 'count': 41, 'length': 173.3},
#  {'_id': 'Orkney Islands', 'count': 32, 'length': 163.8},
#  {'_id': 'Enfield', 'count': 50, 'length': 91.6},
#  {'_id': 'Argyll & Bute', 'count': 76, 'length': 796.9},
#  {'_id': 'Nottinghamshire', 'count': 211, 'length': 654.65},
#  {'_id': 'Denbighshire', 'count': 54, 'length': 206.8},
#  {'_id': 'Suffolk', 'count': 217, 'length': 707.29},
#  {'_id': 'Kingston upon Hull, City of', 'count': 34, 'length': 45.75},
#  {'_id': 'The Vale of Glamorgan', 'count': 30, 'length': 74.67},
#  {'_id': 'Gwynedd', 'count': 82, 'length': 509.71999999999997},
#  {'_id': 'Gateshead', 'count': 60, 'length': 79.37},
#  {'_id': 'Leeds', 'count': 190, 'length': 372.47},
#  {'_id': 'Sefton', 'count': 75, 'length': 95.0},
#  {'_id': 'Manchester', 'count': 153, 'length': 134.1},
#  {'_id': 'Stoke-on-Trent', 'count': 97, 'length': 104.6},
#  {'_id': 'Carmarthenshire', 'count': 80, 'length': 397.2},
#  {'_id': 'West Dunbartonshire', 'count': 36, 'length': 64.0},
#  {'_id': 'East Lothian', 'count': 58, 'length': 165.48},
#  {'_id': 'Flintshire', 'count': 68, 'length': 195.0},
#  {'_id': 'Pembrokeshire', 'count': 61, 'length': 270.7},
#  {'_id': 'City of Edinburgh', 'count': 84, 'length': 160.6},
#  {'_id': 'East Riding of Yorkshire', 'count': 88, 'length': 401.4},
#  {'_id': 'Falkirk', 'count': 80, 'length': 148.1},
#  {'_id': 'Aberdeenshire', 'count': 127, 'length': 884.3},
#  {'_id': 'Renfrewshire', 'count': 50, 'length': 100.7},
#  {'_id': 'Hackney', 'count': 56, 'length': 35.300000000000004},
#  {'_id': 'Clackmannanshire', 'count': 18, 'length': 52.4},
#  {'_id': 'Swansea', 'count': 39, 'length': 113.6},
#  {'_id': 'South Gloucestershire', 'count': 76, 'length': 197.0},
#  {'_id': 'Medway', 'count': 46, 'length': 75.4},
#  {'_id': 'Perth & Kinross', 'count': 114, 'length': 661.1},
#  {'_id': 'Aberdeen City', 'count': 58, 'length': 87.8},
#  {'_id': 'Highland', 'count': 206, 'length': 2344.8},
#  {'_id': 'Neath Port Talbot', 'count': 54, 'length': 160.01},
#  {'_id': 'Norfolk', 'count': 207, 'length': 928.7},
#  {'_id': 'West Berkshire', 'count': 45, 'length': 170.9},
#  {'_id': 'Stockport', 'count': 64, 'length': 97.0},
#  {'_id': 'Dumfries & Galloway', 'count': 146, 'length': 845.24},
#  {'_id': 'North Yorkshire', 'count': 216, 'length': 1101.3},
#  {'_id': 'East Ayrshire', 'count': 62, 'length': 196.7},
#  {'_id': 'Newport', 'count': 28, 'length': 76.8},
#  {'_id': 'North Ayrshire', 'count': 44, 'length': 156.01},
#  {'_id': 'Southampton', 'count': 51, 'length': 57.4},
#  {'_id': 'South Tyneside', 'count': 34, 'length': 54.3},
#  {'_id': 'Ceredigion', 'count': 42, 'length': 274.5},
#  {'_id': 'North East Lincolnshire', 'count': 40, 'length': 84.5},
#  {'_id': 'Bury', 'count': 45, 'length': 75.8},
#  {'_id': 'Lambeth', 'count': 80, 'length': 54.72},
#  {'_id': 'Warrington', 'count': 72, 'length': 134.6},
#  {'_id': 'Inverclyde', 'count': 36, 'length': 59.6},
#  {'_id': 'Stockton-on-Tees', 'count': 70, 'length': 101.9},
#  {'_id': 'Derby', 'count': 66, 'length': 74.23},
#  {'_id': 'Kingston upon Thames', 'count': 49, 'length': 44.3},
#  {'_id': 'Derbyshire', 'count': 259, 'length': 745.74},
#  {'_id': 'Northumberland', 'count': 150, 'length': 604.93},
#  {'_id': 'Hampshire', 'count': 324, 'length': 934.8},
#  {'_id': 'Southwark', 'count': 94, 'length': 54.0},
#  {'_id': 'Lewisham', 'count': 45, 'length': 38.0},
#  {'_id': 'Thurrock', 'count': 59, 'length': 88.78},
#  {'_id': 'Wandsworth', 'count': 71, 'length': 54.5},
#  {'_id': 'Shropshire', 'count': 135, 'length': 572.26},
#  {'_id': 'Dundee City', 'count': 28, 'length': 46.4},
#  {'_id': 'Kensington and Chelsea', 'count': 53, 'length': 30.4},
#  {'_id': 'Ealing', 'count': 48, 'length': 54.2},
#  {'_id': 'Scottish Borders', 'count': 94, 'length': 621.2},
#  {'_id': 'Hounslow', 'count': 76, 'length': 79.9},
#  {'_id': 'Blackburn with Darwen', 'count': 45, 'length': 62.4},
#  {'_id': 'Slough', 'count': 25, 'length': 31.0},
#  {'_id': 'Bristol, City of', 'count': 101, 'length': 105.3},
#  {'_id': 'Wokingham', 'count': 47, 'length': 95.2},
#  {'_id': 'Sandwell', 'count': 77, 'length': 102.07000000000001},
#  {'_id': 'Newham', 'count': 48, 'length': 52.1},
#  {'_id': 'Reading', 'count': 40, 'length': 36.7},
#  {'_id': 'North Lincolnshire', 'count': 55, 'length': 205.5},
#  {'_id': 'Luton', 'count': 26, 'length': 30.95},
#  {'_id': 'Southend-on-Sea', 'count': 21, 'length': 33.5},
#  {'_id': 'Peterborough', 'count': 72, 'length': 127.08},
#  {'_id': 'Worcestershire', 'count': 223, 'length': 564.22},
#  {'_id': 'Isle of Wight', 'count': 38, 'length': 121.35},
#  {'_id': 'Hartlepool', 'count': 20, 'length': 45.8},
#  {'_id': 'East Sussex', 'count': 147, 'length': 440.4},
#  {'_id': 'Croydon', 'count': 66, 'length': 77.2},
#  {'_id': 'Westminster', 'count': 110, 'length': 60.0},
#  {'_id': 'Birmingham', 'count': 151, 'length': 222.4},
#  {'_id': 'Brighton and Hove', 'count': 49, 'length': 59.67},
#  {'_id': 'Leicester', 'count': 55, 'length': 70.0},
#  {'_id': 'Wolverhampton', 'count': 44, 'length': 61.8},
#  {'_id': 'West Lothian', 'count': 64, 'length': 181.7},
#  {'_id': 'Dorset', 'count': 86, 'length': 448.7},
#  {'_id': 'Oxfordshire', 'count': 191, 'length': 697.1},
#  {'_id': 'Camden', 'count': 78, 'length': 38.0},
#  {'_id': 'Hammersmith and Fulham', 'count': 34, 'length': 32.09},
#  {'_id': 'West Cheshire', 'count': 137, 'length': 353.5},
#  {'_id': 'Salford', 'count': 95, 'length': 115.9},
#  {'_id': 'North Lanarkshire', 'count': 107, 'length': 200.5},
#  {'_id': 'Walsall', 'count': 54, 'length': 90.2},
#  {'_id': 'Solihull', 'count': 32, 'length': 76.5},
#  {'_id': 'Coventry', 'count': 40, 'length': 58.1},
#  {'_id': 'Herefordshire, County of', 'count': 91, 'length': 454.7},
#  {'_id': 'Hertfordshire', 'count': 294, 'length': 602.6},
#  {'_id': 'Barking and Dagenham', 'count': 27, 'length': 37.1},
#  {'_id': 'Harrow', 'count': 31, 'length': 41.4},
#  {'_id': 'Sheffield', 'count': 94, 'length': 161.7},
#  {'_id': 'Bolton', 'count': 84, 'length': 118.6},
#  {'_id': 'Oldham', 'count': 72, 'length': 106.6},
#  {'_id': 'Knowsley', 'count': 46, 'length': 68.5},
#  {'_id': 'Darlington', 'count': 31, 'length': 73.5},
#  {'_id': 'Haringey', 'count': 46, 'length': 37.1},
#  {'_id': 'Merton', 'count': 37, 'length': 39.9},
#  {'_id': 'Bromley', 'count': 51, 'length': 89.6},
#  {'_id': 'Waltham Forest', 'count': 40, 'length': 47.9},
#  {'_id': 'Moray', 'count': 42, 'length': 256.6},
#  {'_id': 'Essex', 'count': 245, 'length': 705.62},
#  {'_id': 'Middlesbrough', 'count': 36, 'length': 44.7},
#  {'_id': 'Tameside', 'count': 57, 'length': 81.60000000000001},
#  {'_id': 'West Sussex', 'count': 212, 'length': 572.81},
#  {'_id': 'North Tyneside', 'count': 74, 'length': 90.05},
#  {'_id': 'Swindon', 'count': 33, 'length': 80.15},
#  {'_id': 'Richmond upon Thames', 'count': 59, 'length': 61.9},
#  {'_id': 'Windsor and Maidenhead', 'count': 66, 'length': 99.6},
#  {'_id': 'Bracknell Forest', 'count': 32, 'length': 49.6},
#  {'_id': 'Bournemouth', 'count': 26, 'length': 38.7},
#  {'_id': 'Dudley', 'count': 81, 'length': 98.88},
#  {'_id': 'Brent', 'count': 50, 'length': 52.8},
#  {'_id': 'Milton Keynes', 'count': 36, 'length': 108.1},
#  {'_id': 'Kirklees', 'count': 96, 'length': 232.7},
#  {'_id': 'Redcar and Cleveland', 'count': 25, 'length': 93.6},
#  {'_id': 'North Somerset', 'count': 34, 'length': 122.2},
#  {'_id': 'Poole', 'count': 37, 'length': 44.2}]
